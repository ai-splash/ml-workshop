# %% [markdown]
# # Python Crash Course
#
# Please note, this is not meant to be a comprehensive overview of Python or programming in general, if you have no programming experience, you should probably take my other course: [Complete Python Bootcamp](https://www.udemy.com/complete-python-bootcamp/?couponCode=PY20) instead.
#
# **This notebook is just a code reference for the videos, no written explanations here**
#
# This notebook will just go through the basic topics in order:
#
# * Data types
#     * Numbers
#     * Strings
#     * Printing
#     * Lists
#     * Dictionaries
#     * Booleans
#     * Tuples
#     * Sets
# * Comparison Operators
# * if,elif, else Statements
# * for Loops
# * while Loops
# * range()
# * list comprehension
# * functions
# * lambda expressions
# * map and filter
# * methods
# ____

# %% [markdown]
# ### Machine Learning Experts in India

# %%
from IPython.display import Image

# %%
Image(filename="./images/yoga.jpeg")

# %%
Image(filename="./anto.jpg",width=400)

# %%
Image(filename="./images/PicsArt_02-17-05.53.18.jpg", width=300)

# %%
Image(filename="./images/Screenshot_20190220_102049.jpg", width=450)

# %% [markdown]
# ## Data types
#
# ### Numbers

# %%
1 + 1
# Out:
# 2

# %%
1 * 3
# Out:
# 3

# %%
1 / 2
# Out:
# 0.5

# %%
2 ** 4
# Out:
# 16

# %%
4 % 2
# Out:
# 0

# %%
5 % 2
# Out:
# 1

# %%
(2 + 3) * (5 + 5)
# Out:
# 50

# %% [markdown]
# ### Variable Assignment

# %%
# Can not start with number or special characters
name_of_var = 2

# %%
x = 2
y = 3

# %%
z = x + y

# %%
z
# Out:
# 5

# %% [markdown]
# ### Strings

# %%
'single quotes'
# Out:
# 'single quotes'

# %%
"double quotes"
# Out:
# 'double quotes'

# %%
" wrap lot's of other quotes"
# Out:
# " wrap lot's of other quotes"

# %% [markdown]
# ### Printing

# %%
x = 'hello'

# %%
x
# Out:
# 'hello'

# %%
print(x)
# Out:
# hello

# %%
num = 12
name = 'Sam'

# %%
print('My number is: {one}, and my name is: {two}'.format(one=num,two=name))
# Out:
# My number is: 12, and my name is: Sam

# %%
print('My number is: {}, and my name is: {}'.format(num,name))
# Out:
# My number is: 12, and my name is: Sam

# %% [markdown]
# ### Lists

# %%
[1,2,3]
# Out:
# [1, 2, 3]

# %%
['hi',1,[1,2]]
# Out:
# ['hi', 1, [1, 2]]

# %%
my_list = ['a','b','c']

# %%
my_list.append('d')

# %%
my_list
# Out:
# ['a', 'b', 'c', 'd']

# %%
my_list[0]
# Out:
# 'a'

# %%
my_list[1]
# Out:
# 'b'

# %%
my_list[1:]
# Out:
# ['b', 'c', 'd']

# %%
my_list[:1]
# Out:
# ['a']

# %%
my_list[0] = 'NEW'

# %%
my_list
# Out:
# ['NEW', 'b', 'c', 'd']

# %%
nest = [1,2,3,[4,5,['target']]]

# %%
nest[3]
# Out:
# [4, 5, ['target']]

# %%
nest[3][2]
# Out:
# ['target']

# %%
nest[3][2][0]
# Out:
# 'target'

# %% [markdown]
# ### Dictionaries

# %%
d = {'key1':'item1','key2':'item2'}

# %%
d
# Out:
# {'key1': 'item1', 'key2': 'item2'}

# %%
d['key1']
# Out:
# 'item1'

# %% [markdown]
# ### Booleans

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %% [markdown]
# ### Tuples

# %%
t = (1,2,3)

# %%
t[0]
# Out:
# 1

# %%
t[0] = 'NEW'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-97e4e33b36c2> in <module>()
# ----> 1 t[0] = 'NEW'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Sets

# %%
{1,2,3}
# Out:
# {1, 2, 3}

# %%
{1,2,3,1,2,1,2,3,3,3,3,2,2,2,1,1,2}
# Out:
# {1, 2, 3}

# %% [markdown]
# ## Comparison Operators

# %%
1 > 2
# Out:
# False

# %%
1 < 2
# Out:
# True

# %%
1 >= 1
# Out:
# True

# %%
1 <= 4
# Out:
# True

# %%
1 == 1
# Out:
# True

# %%
'hi' == 'bye'
# Out:
# False

# %% [markdown]
# ## Logic Operators

# %%
(1 > 2) and (2 < 3)
# Out:
# False

# %%
(1 > 2) or (2 < 3)
# Out:
# True

# %%
(1 == 2) or (2 == 3) or (4 == 4)
# Out:
# True

# %% [markdown]
# ## if,elif, else Statements

# %%
if 1 < 2:
    print('Yep!')
# Out:
# Yep!

# %%
if 1 < 2:
    print('yep!')
# Out:
# yep!

# %%
if 1 < 2:
    print('first')
else:
    print('last')
# Out:
# first

# %%
if 1 > 2:
    print('first')
else:
    print('last')
# Out:
# last

# %%
if 1 == 2:
    print('first')
elif 3 == 3:
    print('middle')
else:
    print('Last')
# Out:
# middle

# %% [markdown]
# ## for Loops

# %%
seq = [1,2,3,4,5]

# %%
for item in seq:
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for item in seq:
    print('Yep')
# Out:
# Yep
# Yep
# Yep
# Yep
# Yep

# %%
for jelly in seq:
    print(jelly+jelly)
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# ## while Loops

# %%
i = 1
while i < 5:
    print('i is: {}'.format(i))
    i = i+1
# Out:
# i is: 1
# i is: 2
# i is: 3
# i is: 4

# %% [markdown]
# ## range()

# %%
range(5)
# Out:
# range(0, 5)

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# ## list comprehension

# %%
x = [1,2,3,4]

# %%
out = []
for item in x:
    out.append(item**2)
print(out)
# Out:
# [1, 4, 9, 16]

# %%
[item**2 for item in x]
# Out:
# [1, 4, 9, 16]

# %% [markdown]
# ## functions

# %%
def my_func(param1='default'):
    """
    Docstring goes here.
    """
    print(param1)

# %%
my_func
# Out:
# <function __main__.my_func>

# %%
my_func()
# Out:
# default

# %%
my_func('new param')
# Out:
# new param

# %%
my_func(param1='new param')
# Out:
# new param

# %%
def square(x):
    return x**2

# %%
out = square(2)

# %%
print(out)
# Out:
# 4

# %% [markdown]
# ## lambda expressions

# %%
def times2(var):
    return var*2

# %%
times2(2)
# Out:
# 4

# %%
lambda var: var*2
# Out:
# <function __main__.<lambda>>

# %% [markdown]
# ## methods

# %%
st = 'hello my name is Sam'

# %%
st.lower()
# Out:
# 'hello my name is sam'

# %%
st.upper()
# Out:
# 'HELLO MY NAME IS SAM'

# %%
st.split()
# Out:
# ['hello', 'my', 'name', 'is', 'Sam']

# %%
tweet = 'Go Sports! #Sports'

# %%
tweet.split('#')
# Out:
# ['Go Sports! ', 'Sports']

# %%
tweet.split('#')[1]
# Out:
# 'Sports'

# %%
d
# Out:
# {'key1': 'item1', 'key2': 'item2'}

# %%
d.keys()
# Out:
# dict_keys(['key2', 'key1'])

# %%
d.items()
# Out:
# dict_items([('key2', 'item2'), ('key1', 'item1')])

# %%
lst = [1,2,3]

# %%
lst.pop()
# Out:
# 3

# %%
lst
# Out:
# [1, 2]

# %%
'x' in [1,2,3]
# Out:
# False

# %%
'x' in ['x','y','z']
# Out:
# True

# %% [markdown]
# # Great Job!
